# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 4
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  1 <- at epoch 0
# [1. 1.] 0
# error :  -1 <- at epoch 1
# [1. 1.] -1
# error :  -1 <- at epoch 1
# [1. 0.] -2
# error :  0 <- at epoch 1
# [1. 0.] -2
# error :  1 <- at epoch 1
# [2. 1.] -1
# error :  0 <- at epoch 2
# [2. 1.] -1
# error :  -1 <- at epoch 2
# [2. 0.] -2
# error :  -1 <- at epoch 2
# [1. 0.] -3
# error :  1 <- at epoch 2
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  -1 <- at epoch 3
# [1. 1.] -3
# error :  1 <- at epoch 3
# [2. 2.] -2

# %% [markdown]
# **I**

# %%
#1
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 6
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  1 <- at epoch 0
# [1. 1.] 0
# error :  -1 <- at epoch 1
# [1. 1.] -1
# error :  -1 <- at epoch 1
# [1. 0.] -2
# error :  0 <- at epoch 1
# [1. 0.] -2
# error :  1 <- at epoch 1
# [2. 1.] -1
# error :  0 <- at epoch 2
# [2. 1.] -1
# error :  -1 <- at epoch 2
# [2. 0.] -2
# error :  -1 <- at epoch 2
# [1. 0.] -3
# error :  1 <- at epoch 2
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  -1 <- at epoch 3
# [1. 1.] -3
# error :  1 <- at epoch 3
# [2. 2.] -2
# error :  0 <- at epoch 4
# [2. 2.] -2
# error :  -1 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3

# %%
#2
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([1,0,-1,1])
epochs = 20
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  0 <- at epoch 0
# [0. 0.] 0
# error :  -1 <- at epoch 0
# [ 0. -1.] -1
# error :  -1 <- at epoch 0
# [-1. -1.] -2
# error :  1 <- at epoch 0
# [0. 0.] -1
# error :  1 <- at epoch 1
# [0. 0.] 0
# error :  -1 <- at epoch 1
# [ 0. -1.] -1
# error :  -1 <- at epoch 1
# [-1. -1.] -2
# error :  1 <- at epoch 1
# [0. 0.] -1
# error :  1 <- at epoch 2
# [0. 0.] 0
# error :  -1 <- at epoch 2
# [ 0. -1.] -1
# error :  -1 <- at epoch 2
# [-1. -1.] -2
# error :  1 <- at epoch 2
# [0. 0.] -1
# error :  1 <- at epoch 3
# [0. 0.] 0
# error :  -1 <- at epoch 3
# [ 0. -1.] -1
# error :  -1 <- at epoch 3
# [-1. -1.] -2
# error :  1 <- at epoch 3
# [0. 0.] -1
# error :  1 <- at epoch 4
# [0. 0.] 0
# error :  -1 <- at epoch 4
# [ 0. -1.] -1
# error :  -1 <- at epoch 4
# [-1. -1.] -2
# error :  1 <- at epoch 4
# [0. 0.] -1
# error :  1 <- at epoch 5
# [0. 0.] 0
# error :  -1 <- at epoch 5
# [ 0. -1.] -1
# error :  -1 <- at epoch 5
# [-1. -1.] -2
# error :  1 <- at epoch 5
# [0. 0.] -1
# error :  1 <- at epoch 6
# [0. 0.] 0
# error :  -1 <- at epoch 6
# [ 0. -1.] -1
# error :  -1 <- at epoch 6
# [-1. -1.] -2
# error :  1 <- at epoch 6
# [0. 0.] -1
# error :  1 <- at epoch 7
# [0. 0.] 0
# error :  -1 <- at epoch 7
# [ 0. -1.] -1
# error :  -1 <- at epoch 7
# [-1. -1.] -2
# error :  1 <- at epoch 7
# [0. 0.] -1
# error :  1 <- at epoch 8
# [0. 0.] 0
# error :  -1 <- at epoch 8
# [ 0. -1.] -1
# error :  -1 <- at epoch 8
# [-1. -1.] -2
# error :  1 <- at epoch 8
# [0. 0.] -1
# error :  1 <- at epoch 9
# [0. 0.] 0
# error :  -1 <- at epoch 9
# [ 0. -1.] -1
# error :  -1 <- at epoch 9
# [-1. -1.] -2
# error :  1 <- at epoch 9
# [0. 0.] -1
# error :  1 <- at epoch 10
# [0. 0.] 0
# error :  -1 <- at epoch 10
# [ 0. -1.] -1
# error :  -1 <- at epoch 10
# [-1. -1.] -2
# error :  1 <- at epoch 10
# [0. 0.] -1
# error :  1 <- at epoch 11
# [0. 0.] 0
# error :  -1 <- at epoch 11
# [ 0. -1.] -1
# error :  -1 <- at epoch 11
# [-1. -1.] -2
# error :  1 <- at epoch 11
# [0. 0.] -1
# error :  1 <- at epoch 12
# [0. 0.] 0
# error :  -1 <- at epoch 12
# [ 0. -1.] -1
# error :  -1 <- at epoch 12
# [-1. -1.] -2
# error :  1 <- at epoch 12
# [0. 0.] -1
# error :  1 <- at epoch 13
# [0. 0.] 0
# error :  -1 <- at epoch 13
# [ 0. -1.] -1
# error :  -1 <- at epoch 13
# [-1. -1.] -2
# error :  1 <- at epoch 13
# [0. 0.] -1
# error :  1 <- at epoch 14
# [0. 0.] 0
# error :  -1 <- at epoch 14
# [ 0. -1.] -1
# error :  -1 <- at epoch 14
# [-1. -1.] -2
# error :  1 <- at epoch 14
# [0. 0.] -1
# error :  1 <- at epoch 15
# [0. 0.] 0
# error :  -1 <- at epoch 15
# [ 0. -1.] -1
# error :  -1 <- at epoch 15
# [-1. -1.] -2
# error :  1 <- at epoch 15
# [0. 0.] -1
# error :  1 <- at epoch 16
# [0. 0.] 0
# error :  -1 <- at epoch 16
# [ 0. -1.] -1
# error :  -1 <- at epoch 16
# [-1. -1.] -2
# error :  1 <- at epoch 16
# [0. 0.] -1
# error :  1 <- at epoch 17
# [0. 0.] 0
# error :  -1 <- at epoch 17
# [ 0. -1.] -1
# error :  -1 <- at epoch 17
# [-1. -1.] -2
# error :  1 <- at epoch 17
# [0. 0.] -1
# error :  1 <- at epoch 18
# [0. 0.] 0
# error :  -1 <- at epoch 18
# [ 0. -1.] -1
# error :  -1 <- at epoch 18
# [-1. -1.] -2
# error :  1 <- at epoch 18
# [0. 0.] -1
# error :  1 <- at epoch 19
# [0. 0.] 0
# error :  -1 <- at epoch 19
# [ 0. -1.] -1
# error :  -1 <- at epoch 19
# [-1. -1.] -2
# error :  1 <- at epoch 19
# [0. 0.] -1

# %%
#2
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([1,-1,0,1])
epochs = 4
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# Epoch: 0
# error: -1 <- at epoch 3
# error: 0 <- at epoch 3
# error: 0 <- at epoch 3
# error: 1 <- at epoch 3
#
# Epoch: 1
# error: -1 <- at epoch 3
# error: -1 <- at epoch 3
# error: 0 <- at epoch 3
# error: 1 <- at epoch 3
#
# Epoch: 2
# error: 0 <- at epoch 3
# error: -1 <- at epoch 3
# error: 0 <- at epoch 3
# error: 1 <- at epoch 3
#
# Epoch: 3
# error: 0 <- at epoch 3
# error: -1 <- at epoch 3
# error: -1 <- at epoch 3
# error: 1 <- at epoch 3
#
# Epoch: 4
# error: 0 <- at epoch 3
# error: 0 <- at epoch 3
# error: -1 <- at epoch 3
# error: 1 <- at epoch 3
#
# Epoch: 5
# error: 0 <- at epoch 3
# error: -1 <- at epoch 3
# error: 0 <- at epoch 3
# error: 0 <- at epoch 3
#
# Epoch: 6
# error: 0 <- at epoch 3
# error: 0 <- at epoch 3
# error: 0 <- at epoch 3
# error: 0 <- at epoch 3
# Training stopped: zero error for all inputs
